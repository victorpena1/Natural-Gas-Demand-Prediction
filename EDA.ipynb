# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Always make it pretty.
plt.style.use('ggplot')

# %%
df = pd.read_csv('data/temp_all_80_19.csv')

# %%
df.head(2)
# Out:
#      DateTime     Temp
# 0  1980-01-01  33.3999
# 1  1980-01-02  31.6287

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14324 entries, 0 to 14323
# Data columns (total 2 columns):
# DateTime    14324 non-null object
# Temp        14324 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 223.9+ KB

# %%
def df_cleaner(df):
    #df['DateTime'] = df['DateTime'].map(lambda x:x[:-6])
    df['DateTime'] = pd.to_datetime(df['DateTime'])
    return df

# %%
df_temp = df_cleaner(df)

# %%
df_temp.head()
# Out:
#     DateTime     Temp
# 0 1980-01-01  33.3999
# 1 1980-01-02  31.6287
# 2 1980-01-03  28.9974
# 3 1980-01-04  28.7272
# 4 1980-01-05  28.8493

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(df_temp['DateTime'], df_temp['Temp'])
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
import datetime as dt
include = df[df['DateTime'].dt.year == 2008]
#exclude = df[df['Date'].dt.year != year]

# %%
df2 = pd.read_excel('data/reserves/NG_wet_nonasso_asso_dry_sum.xls', header= 2)

# %%
df2.tail()
# Out:
#          Date  \
# 78 2013-06-30
# 79 2014-06-30
# 80 2015-06-30
# 81 2016-06-30
# 82 2017-06-30
#
#     U.S. Natural Gas, Wet After Lease Separation Proved Reserves (Billion Cubic Feet)  \
# 78                                           353994.0
# 79                                           388841.0
# 80                                           324303.0
# 81                                           341133.0
# 82                                           464292.0
#
#     U.S. Nonassociated Natural Gas, Wet After Lease Separation, Proved Reserves (Billion Cubic Feet)  \
# 78                                           295504.0
# 79                                           319724.0
# 80                                           258807.0
# 81                                           268913.0
# 82                                           364846.0
#
#     U.S. Associated-Dissolved Natural Gas, Wet After Lease Separation, Proved Reserves (Billion Cubic Feet)  \
# 78                                            58490.0
# 79                                            69117.0
# 80                                            65496.0
# 81                                            72220.0
# 82                                            99446.0
#
#     U.S. Dry Natural Gas Expected Future Production (Billion Cubic Feet)  \
# 78                                             338264
# 79                                             368704
# 80                                             307730
# 81                                             322234
# 82                                             438460
#
#     U.S. Natural Gas Plant Liquids, Proved Reserves (Million Barrels)
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN

# %%
df_rev = df2[['Date', 'U.S. Natural Gas, Wet After Lease Separation Proved Reserves (Billion Cubic Feet)']]
df_rev.rename(index=str, columns={"Date": "DateTime", 'U.S. Natural Gas, Wet After Lease Separation Proved Reserves (Billion Cubic Feet)': "Reserves BCFE"}, inplace = True)
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_rev.tail()
# Out:
#      DateTime  Reserves BCFE
# 78 2013-06-30       353994.0
# 79 2014-06-30       388841.0
# 80 2015-06-30       324303.0
# 81 2016-06-30       341133.0
# 82 2017-06-30       464292.0

# %%
df3 = pd.read_csv('data/weekly_Underground_Storage.csv')
df3 .rename(index=str, columns={"Week of": "DateTime", 'Lower 48 States Natural Gas Working Underground Storage Billion Cubic Feet': "Storage BCFE"}, inplace = True)
df_stor = df_cleaner(df3)

# %%
df_stor.head()
# Out:
#     DateTime  Storage BCFE
# 0 2019-03-22          1107
# 1 2019-03-15          1143
# 2 2019-03-08          1190
# 3 2019-03-01          1390
# 4 2019-02-22          1539

# %%
df4 = pd.read_csv('data/monthly_production.csv')

# %%
df4.rename(index=str, columns={"Month": "DateTime", "U.S. Natural Gas Gross Withdrawals  Million Cubic Feet": "Production MMCF"}, inplace = True)

# %%
df_prod = df_cleaner(df4)

# %%
df_prod.head()
# Out:
#     DateTime  Production MMCF
# 0 2019-01-01          3352124
# 1 2018-12-01          3351564
# 2 2018-11-01          3233430
# 3 2018-10-01          3272022
# 4 2018-09-01          3134786

# %%
df5 = pd.read_csv('data/Henry_Hub_Natural_Gas_Spot_Price.csv')

# %%
df5.rename(index=str, columns={"Day": "DateTime", 'Henry Hub Natural Gas Spot Price Dollars per Million Btu': 'Henry Hub Price $/MMBtu'}, inplace = True)

# %%
df_price = df_cleaner(df5)

# %%
df6 = pd.read_csv('data/Consumption.csv')
df6.rename(index=str, columns={"Month": "DateTime", 'U.S. Natural Gas Total Consumption  Million Cubic Feet': 'Consumption MMCF'}, inplace = True)

# %%
df_cons = df_cleaner(df6)

# %%
df_cons.head(5)
# Out:
#     DateTime  Consumption MMCF
# 0 2019-01-01           3386730
# 1 2018-12-01           2969569
# 2 2018-11-01           2688953
# 3 2018-10-01           2276313
# 4 2018-09-01           2158676

# %%
df_temp.tail(10)
# Out:
#         DateTime     Temp
# 14314 2019-03-04  20.6935
# 14315 2019-03-05  23.3083
# 14316 2019-03-06  27.2867
# 14317 2019-03-07  31.3371
# 14318 2019-03-08  35.1228
# 14319 2019-03-09  37.1899
# 14320 2019-03-10  36.4206
# 14321 2019-03-11  36.5454
# 14322 2019-03-12  39.8039
# 14323 2019-03-13  41.4588

# %%
df_prod.head(1)
# Out:
#     DateTime  Production MMCF
# 0 2019-01-01          3352124

# %%
df_stor.head(5)
# Out:
#     DateTime  Storage BCFE
# 0 2019-03-22          1107
# 1 2019-03-15          1143
# 2 2019-03-08          1190
# 3 2019-03-01          1390
# 4 2019-02-22          1539

# %%
df_rev.head(1)
# Out:
#     DateTime  Reserves BCFE
# 0 1925-06-30            NaN

# %%
df_test = df_price
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5577 entries, 0 to 5576
# Data columns (total 2 columns):
# DateTime                   5577 non-null datetime64[ns]
# Henry Hub Price $/MMBtu    5576 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 130.7+ KB

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14324 entries, 0 to 14323
# Data columns (total 2 columns):
# DateTime    14324 non-null datetime64[ns]
# Temp        14324 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 223.9 KB

# %%
#pd.set_option('display.max_rows', 500)
df_pi_tem = df_test.join(df_temp.set_index('DateTime'), on='DateTime')

# %%
df_pi_tem_pro = df_pi_tem.join(df_prod.set_index('DateTime'), on='DateTime')

# %%
df_pi_tem_pro_stor = df_pi_tem_pro.join(df_stor.set_index('DateTime'), on='DateTime')

# %%
df_pi_tem_pro_stor.join(df_rev.set_index('DateTime'), on='DateTime')
# Out:
#        DateTime  Henry Hub Price $/MMBtu     Temp  Production MMCF  \
# 0    2019-03-11                     2.86  36.5454              NaN
# 1    2019-03-08                     2.90  35.1228              NaN
# 2    2019-03-07                     2.90  31.3371              NaN
# 3    2019-03-06                     3.18  27.2867              NaN
# 4    2019-03-05                     3.18  23.3083              NaN
# 5    2019-03-04                     4.25  20.6935              NaN
# 6    2019-03-01                     3.19  32.2356              NaN
# 7    2019-02-28                     2.89  31.3455              NaN
# 8    2019-02-27                     2.89  30.8332              NaN
# 9    2019-02-26                     2.74  28.1669              NaN
# 10   2019-02-25                     2.84  25.8399              NaN
# 11   2019-02-22                     2.74  29.7369              NaN
# 12   2019-02-21                     2.73  29.1303              NaN
# 13   2019-02-20                     2.69  27.3555              NaN
# 14   2019-02-19                     2.69  22.1778              NaN
# 15   2019-02-15                     2.59  32.4081              NaN
# 16   2019-02-14                     2.61  34.4626              NaN
# 17   2019-02-13                     2.61  31.3905              NaN
# 18   2019-02-12                     2.71  30.4407              NaN
# 19   2019-02-11                     2.76  28.9396              NaN
# 20   2019-02-08                     2.66  20.9298              NaN
# 21   2019-02-07                     2.62  27.4735              NaN
# 22   2019-02-06                     2.58  31.6645              NaN
# 23   2019-02-05                     2.54  33.0489              NaN
# 24   2019-02-04                     2.57  36.2502              NaN
# 25   2019-02-01                     2.70  31.2762              NaN
# 26   2019-01-31                     2.82  23.1021              NaN
# 27   2019-01-30                     3.00  18.8830              NaN
# 28   2019-01-29                     2.94  23.2930              NaN
# 29   2019-01-28                     3.05  29.6499              NaN
# ...         ...                      ...      ...              ...
# 5547 1997-02-18                     1.84  41.3559              NaN
# 5548 1997-02-14                     2.12  32.0373              NaN
# 5549 1997-02-13                     2.22  28.5906              NaN
# 5550 1997-02-12                     2.42  28.9200              NaN
# 5551 1997-02-11                     2.34  29.7721              NaN
# 5552 1997-02-10                     2.42  29.5362              NaN
# 5553 1997-02-07                     2.39  28.9931              NaN
# 5554 1997-02-06                     2.51  29.4024              NaN
# 5555 1997-02-05                     2.65  32.1508              NaN
# 5556 1997-02-04                     2.59  35.3541              NaN
# 5557 1997-02-03                     2.49  37.6714              NaN
# 5558 1997-01-31                     2.77  38.4352              NaN
# 5559 1997-01-30                     2.86  31.6481              NaN
# 5560 1997-01-29                     2.91  25.8489              NaN
# 5561 1997-01-28                     3.05  24.7287              NaN
# 5562 1997-01-27                     2.98  26.6218              NaN
# 5563 1997-01-24                     2.62  30.2472              NaN
# 5564 1997-01-23                     2.96  31.7446              NaN
# 5565 1997-01-22                     3.05  35.1477              NaN
# 5566 1997-01-21                     2.99  36.7817              NaN
# 5567 1997-01-20                     3.26  34.7077              NaN
# 5568 1997-01-17                     3.91  15.7626              NaN
# 5569 1997-01-16                     4.71  17.6200              NaN
# 5570 1997-01-15                     4.34  24.0031              NaN
# 5571 1997-01-14                     4.01  17.1041              NaN
# 5572 1997-01-13                     4.00  12.0574              NaN
# 5573 1997-01-10                     3.92  21.5541              NaN
# 5574 1997-01-09                     3.61  27.1393              NaN
# 5575 1997-01-08                     3.80  27.2858              NaN
# 5576 1997-01-07                     3.82  24.6924              NaN
#
#       Storage BCFE  Reserves BCFE
# 0              NaN            NaN
# 1           1190.0            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# 5              NaN            NaN
# 6           1390.0            NaN
# 7              NaN            NaN
# 8              NaN            NaN
# 9              NaN            NaN
# 10             NaN            NaN
# 11          1539.0            NaN
# 12             NaN            NaN
# 13             NaN            NaN
# 14             NaN            NaN
# 15          1705.0            NaN
# 16             NaN            NaN
# 17             NaN            NaN
# 18             NaN            NaN
# 19             NaN            NaN
# 20          1882.0            NaN
# 21             NaN            NaN
# 22             NaN            NaN
# 23             NaN            NaN
# 24             NaN            NaN
# 25          1960.0            NaN
# 26             NaN            NaN
# 27             NaN            NaN
# 28             NaN            NaN
# 29             NaN            NaN
# ...            ...            ...
# 5547           NaN            NaN
# 5548           NaN            NaN
# 5549           NaN            NaN
# 5550           NaN            NaN
# 5551           NaN            NaN
# 5552           NaN            NaN
# 5553           NaN            NaN
# 5554           NaN            NaN
# 5555           NaN            NaN
# 5556           NaN            NaN
# 5557           NaN            NaN
# 5558           NaN            NaN
# 5559           NaN            NaN
# 5560           NaN            NaN
# 5561           NaN            NaN
# 5562           NaN            NaN
# 5563           NaN            NaN
# 5564           NaN            NaN
# 5565           NaN            NaN
# 5566           NaN            NaN
# 5567           NaN            NaN
# 5568           NaN            NaN
# 5569           NaN            NaN
# 5570           NaN            NaN
# 5571           NaN            NaN
# 5572           NaN            NaN
# 5573           NaN            NaN
# 5574           NaN            NaN
# 5575           NaN            NaN
# 5576           NaN            NaN
#
# [5577 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(df_price['DateTime'], df_price['Henry Hub Price $/MMBtu'])
ax.plot(df_temp['DateTime'], df_temp['Temp'])

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(df_prod['DateTime'], df_prod['Production MMCF'])

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(df_stor['DateTime'], df_stor['Storage BCFE'])

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(df_rev['DateTime'], df_rev['Reserves BCFE'])

# %%
year = '2008'
end = '2019'
period = pd.Period(year, freq='Y')
end_period = pd.Period(end, freq='Y')
df_time = pd.Series(pd.DatetimeIndex(start=period.start_time, end=end_period.end_time, freq='D')).to_frame('DateTime')
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   """

# %%
df_ti_pi= df_time.join(df_price.set_index('DateTime'), on='DateTime')
df_pi_tem = df_ti_pi.join(df_temp.set_index('DateTime'), on='DateTime')
df_pi_tem_pro = df_pi_tem.join(df_prod.set_index('DateTime'), on='DateTime')
df_pi_tem_pro_stor = df_pi_tem_pro.join(df_stor.set_index('DateTime'), on='DateTime')
df_pi_tem_pro_stor_rev = df_pi_tem_pro_stor.join(df_rev.set_index('DateTime'), on='DateTime')
df_all = df_pi_tem_pro_stor_rev.join(df_cons.set_index('DateTime'), on='DateTime')

# %%
df_all.iloc[728:740]
# Out:
#       DateTime  Henry Hub Price $/MMBtu     Temp  Production MMCF  \
# 728 2009-12-29                     6.01  25.2061              NaN
# 729 2009-12-30                     5.78  28.3431              NaN
# 730 2009-12-31                     5.82  28.3233              NaN
# 731 2010-01-01                      NaN  26.0317        2210163.0
# 731 2010-01-01                      NaN  26.0317        2210163.0
# 732 2010-01-02                      NaN  24.2249              NaN
# 733 2010-01-03                      NaN  23.5537              NaN
# 734 2010-01-04                     6.09  23.2831              NaN
# 735 2010-01-05                     6.19  24.5469              NaN
# 736 2010-01-06                     6.47  25.2813              NaN
# 737 2010-01-07                     7.51  21.0909              NaN
# 738 2010-01-08                     6.56  18.5464              NaN
#
#      Storage BCFE  Reserves BCFE  Consumption MMCF
# 728           NaN            NaN               NaN
# 729           NaN            NaN               NaN
# 730           NaN            NaN               NaN
# 731        3117.0            NaN         2809788.0
# 731        3117.0            NaN         2809788.0
# 732           NaN            NaN               NaN
# 733           NaN            NaN               NaN
# 734           NaN            NaN               NaN
# 735           NaN            NaN               NaN
# 736           NaN            NaN               NaN
# 737           NaN            NaN               NaN
# 738        2850.0            NaN               NaN

# %%
df_all_test = df_all

# %%
df_all_test2 = df_all_test[(df_all_test.DateTime > '2009-12-31') & (df_all_test.DateTime < '2019-03-12')]

# %%
df_almost = df_all_test.fillna(method='ffill')

# %%
df_fine = df_almost[(df_almost.DateTime > '2009-12-31') & (df_almost.DateTime < '2019-03-12')]

# %%
df_fine.head(10)
# Out:
#       DateTime  Henry Hub Price $/MMBtu     Temp  Production MMCF  \
# 731 2010-01-01                     5.82  26.0317        2210163.0
# 731 2010-01-01                     5.82  26.0317        2210163.0
# 732 2010-01-02                     5.82  24.2249        2210163.0
# 733 2010-01-03                     5.82  23.5537        2210163.0
# 734 2010-01-04                     6.09  23.2831        2210163.0
# 735 2010-01-05                     6.19  24.5469        2210163.0
# 736 2010-01-06                     6.47  25.2813        2210163.0
# 737 2010-01-07                     7.51  21.0909        2210163.0
# 738 2010-01-08                     6.56  18.5464        2210163.0
# 739 2010-01-09                     6.56  21.1352        2210163.0
#
#      Storage BCFE  Reserves BCFE  Consumption MMCF
# 731        3117.0       283879.0         2809788.0
# 731        3117.0       283879.0         2809788.0
# 732        3117.0       283879.0         2809788.0
# 733        3117.0       283879.0         2809788.0
# 734        3117.0       283879.0         2809788.0
# 735        3117.0       283879.0         2809788.0
# 736        3117.0       283879.0         2809788.0
# 737        3117.0       283879.0         2809788.0
# 738        2850.0       283879.0         2809788.0
# 739        2850.0       283879.0         2809788.0

# %%
fig, ax1 = plt.subplots(figsize=(15,5))

color = 'tab:red'
ax1.set_xlabel('time (Years)')
ax1.set_ylabel('Price', color=color)
ax1.plot(df_fine['DateTime'], df_fine['Henry Hub Price $/MMBtu'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(df_fine['DateTime'], df_fine['Temp'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()

color = 'tab:green'
ax3.set_ylabel('Production', color=color)  # we already handled the x-label with ax1
ax3.plot(df_fine['DateTime'], df_fine['Production MMCF'], color=color)
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()

color = 'tab:orange'
ax4.set_ylabel('Storage', color=color)  # we already handled the x-label with ax1
ax4.plot(df_fine['DateTime'], df_fine['Storage BCFE'], color=color)
ax4.tick_params(axis='y', labelcolor=color)

ax5 = ax1.twinx()

color = 'tab:pink'
ax5.set_ylabel('Reserves', color=color)  # we already handled the x-label with ax1
ax5.plot(df_fine['DateTime'], df_fine['Reserves BCFE'], color=color)
ax5.tick_params(axis='y', labelcolor=color)

ax6 = ax1.twinx()

color = 'tab:brown'
ax6.set_ylabel('Comsumption', color=color)  # we already handled the x-label with ax1
ax6.plot(df_fine['DateTime'], df_fine['Consumption MMCF'], color=color)
ax6.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
from pandas.plotting import scatter_matrix
fig, ax = plt.subplots(1, 1, figsize=(13, 13))
ax = scatter_matrix(df_fine, ax=ax, diagonal='kde')
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3291: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # we are going to test moving the data to release day to the public to see if there is an effect on the correlation.

# %%
df_all_test_shift = df_all_test

# %%
df_all_test_shift['Storage BCFE']=df_all_test_shift['Storage BCFE'].shift(periods=6)
df_all_test_shift['Production MMCF'] = df_all_test_shift['Production MMCF'].shift(periods=90)
df_all_test_shift['Consumption MMCF'] = df_all_test_shift['Consumption MMCF'].shift(periods=90)
df_all_test_shift['Reserves BCFE'] = df_all_test_shift['Reserves BCFE'].shift(periods=547)

# %%
df_shift_almost = df_all_test_shift.fillna(method='ffill')

# %%
df_shift = df_shift_almost[(df_shift_almost.DateTime > '2009-12-31')& (df_shift_almost.DateTime < '2019-03-12')]
df_shift.head(3)
# Out:
#       DateTime  Henry Hub Price $/MMBtu     Temp  Production MMCF  \
# 731 2010-01-01                     5.82  26.0317        2197157.0
# 731 2010-01-01                     5.82  26.0317        2197157.0
# 732 2010-01-02                     5.82  24.2249        2197157.0
#
#      Storage BCFE  Reserves BCFE  Consumption MMCF
# 731           NaN       255035.0         1666520.0
# 731           NaN       255035.0         1666520.0
# 732           NaN       255035.0         1666520.0

# %%
df_shift['Storage BCFE'] = df_shift['Storage BCFE'].fillna(method = 'bfill')
df_shift.iloc[1]
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# DateTime                   2010-01-01 00:00:00
# Henry Hub Price $/MMBtu                   5.82
# Temp                                   26.0317
# Production MMCF                    2.19716e+06
# Storage BCFE                              3117
# Reserves BCFE                           255035
# Consumption MMCF                   1.66652e+06
# Name: 731, dtype: object

# %%
fig, ax1 = plt.subplots(figsize=(15,5))

color = 'tab:red'
ax1.set_xlabel('time (Years)')
ax1.set_ylabel('Price', color=color)
ax1.plot(df_shift['DateTime'], df_shift['Henry Hub Price $/MMBtu'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Temperature', color=color)  # we already handled the x-label with ax1
ax2.plot(df_shift['DateTime'], df_shift['Temp'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()

color = 'tab:green'
ax3.set_ylabel('Production', color=color)  # we already handled the x-label with ax1
ax3.plot(df_shift['DateTime'], df_shift['Production MMCF'], color=color)
ax3.tick_params(axis='y', labelcolor=color)

ax4 = ax1.twinx()

color = 'tab:orange'
ax4.set_ylabel('Storage', color=color)  # we already handled the x-label with ax1
ax4.plot(df_shift['DateTime'], df_shift['Storage BCFE'], color=color)
ax4.tick_params(axis='y', labelcolor=color)

ax5 = ax1.twinx()

color = 'tab:pink'
ax5.set_ylabel('Reserves', color=color)  # we already handled the x-label with ax1
ax5.plot(df_shift['DateTime'], df_shift['Reserves BCFE'], color=color)
ax5.tick_params(axis='y', labelcolor=color)

ax6 = ax1.twinx()

color = 'tab:brown'
ax6.set_ylabel('Comsumption', color=color)  # we already handled the x-label with ax1
ax6.plot(df_shift['DateTime'], df_shift['Consumption MMCF'], color=color)
ax6.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.tight_layout()

# %%
def plot_trend_data(ax, column_name, df):
    ax.plot(df['DateTime'], df[column_name])
    ax.set_title("Ten years trend of {}".format(column_name))

# %%
data_columns = ['Henry Hub Price $/MMBtu', 'Temp', 'Production MMCF',
       'Storage BCFE', 'Reserves BCFE', 'Consumption MMCF']

# %%
fig, axs = plt.subplots(len(data_columns), figsize=(14, 12))

for ax, column_name in zip(axs, data_columns):
    plot_trend_data(ax, column_name, df_shift)
    
plt.tight_layout()

# %% [markdown]
# #### Some observations:
#
# - the `price` plot shows a more random pattern than the others. it has a non-linear trend over time.
# - The `temperature` plot shows very strong oscillations aligned with seasonality in the northern hemisphere.
# - The `production` plot shows a general increase over time, probably influenced by the increase in shale plays production efficiencies.
# - The `storage` plot shows very strong oscillations aligned with seasonality in the northern hemisphere. In general, storage levels decrease during the winter and increase during the summer.
# - The `reserves` plot shows a general increase over time, probably influenced by the increase in shale plays discoveries in the last few years.
# - The `consumption` plot shows very strong oscillations aligned with seasonality in the northern hemisphere. In general, natural gas consumption levels increase during the winter and decrease during the summer.

# %%
from pandas.plotting import scatter_matrix
fig, ax = plt.subplots(1, 1, figsize=(13, 13))
ax = scatter_matrix(df_shift, ax=ax, diagonal='kde')
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3291: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import datetime

date = datetime.datetime.strptime("2015-06-01 00:00:00",
                                  "%Y-%m-%d %H:%M:%S")
#print date.timetuple().tm_yday

# %%
def doy(x):
    #test = df_shift_final['DateTime'][x]
    date = datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S")
    return date.timetuple().tm_yday

# %%
df_shift_final =df_shift.drop_duplicates(keep='first')

# %%
df_shift_final['DOY'] =df_shift_final['DateTime']
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_shift_final['DOY'] = df_shift_final['DOY'].apply(lambda x : doy(x))
# Out:
# /home/victor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_shift_final.tail()
# Out:
#        DateTime  Henry Hub Price $/MMBtu     Temp  Production MMCF  \
# 4083 2019-03-07                     2.90  31.3371        3351564.0
# 4084 2019-03-08                     2.90  35.1228        3351564.0
# 4085 2019-03-09                     2.90  37.1899        3351564.0
# 4086 2019-03-10                     2.90  36.4206        3351564.0
# 4087 2019-03-11                     2.86  36.5454        3351564.0
#
#       Storage BCFE  Reserves BCFE  Consumption MMCF  DOY
# 4083        1390.0       464292.0         2969569.0   66
# 4084        1390.0       464292.0         2969569.0   67
# 4085        1390.0       464292.0         2969569.0   68
# 4086        1390.0       464292.0         2969569.0   69
# 4087        1390.0       464292.0         2969569.0   70

# %%
df_group = df_shift_final.groupby(by= 'DOY').median()

# %%
df_group.head(2)
# Out:
#      Henry Hub Price $/MMBtu      Temp  Production MMCF  Storage BCFE  \
# DOY
# 1                      3.560  25.22460        2638663.5        3282.0
# 2                      3.505  25.86265        2638663.5        3282.0
#
#      Reserves BCFE  Consumption MMCF
# DOY
# 1         332718.0         1906947.0
# 2         332718.0         1906947.0

# %%
df_group.describe()
# Out:
#        Henry Hub Price $/MMBtu        Temp  Production MMCF  Storage BCFE  \
# count               366.000000  366.000000     3.660000e+02    366.000000
# mean                  3.155861   52.575521     2.587807e+06   2740.758197
# std                   0.215055   15.935294     7.325841e+04    737.391928
# min                   2.750000   25.224600     2.360061e+06   1614.000000
# 25%                   2.985000   36.159150     2.568932e+06   2062.000000
# 50%                   3.100000   52.894750     2.623914e+06   2804.000000
# 75%                   3.307500   68.261700     2.633253e+06   3385.000000
# max                   3.770000   76.558100     2.720187e+06   3840.000000
#
#        Reserves BCFE  Consumption MMCF
# count     366.000000      3.660000e+02
# mean   326083.855191      2.196400e+06
# std      3624.872038      3.597683e+05
# min    324303.000000      1.809291e+06
# 25%    324303.000000      1.906947e+06
# 50%    324303.000000      2.008815e+06
# 75%    324303.000000      2.521108e+06
# max    341133.000000      2.900856e+06

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.set_xlabel('Day of the Year')
ax.set_ylabel('Temperature (F*)')
ax.set_title("Average Temperature in the US 2010-19", fontsize = 13)
ax.scatter(df_shift_final['DOY'], df_shift_final['Temp'], label = 'Temp', alpha =.3)
ax.plot(df_group.index.values, df_group['Temp'] , label = 'Mean Temp', color = 'y')
ax.legend()

# %%
df_group[df_group['Temp'] == df_group['Temp'].max()]
# Out:
#      Henry Hub Price $/MMBtu     Temp  Production MMCF  Storage BCFE  \
# DOY
# 200                     3.11  76.5581        2583873.0        2764.0
#
#      Reserves BCFE  Consumption MMCF
# DOY
# 200       324303.0         1961678.0

# %% [markdown]
# ### The average hottest day for the period of 2010-19 is somewhere around the middle of July.

# %%
df_group[df_group['Temp'] == df_group['Temp'].min()]
# Out:
#      Henry Hub Price $/MMBtu     Temp  Production MMCF  Storage BCFE  \
# DOY
# 1                       3.56  25.2246        2638663.5        3282.0
#
#      Reserves BCFE  Consumption MMCF
# DOY
# 1         332718.0         1906947.0

# %% [markdown]
# ### The average coldest day for the period of 2010-19 is somewhere around early January.

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.set_xlabel('Day of the Year')
ax.set_ylabel('Storage (BCFE)')
ax.set_title("Average Natural Gas Storage in the US 2010-19", fontsize = 13)
ax.scatter(df_shift_final['DOY'], df_shift_final['Storage BCFE'], label = 'Storage', alpha =.3)
ax.plot(df_group.index.values, df_group['Storage BCFE'] , label = 'Mean Storage', color = 'y')
ax.legend()

# %%
df_group[df_group['Storage BCFE'] == df_group['Storage BCFE'].max()]
# Out:
#      Henry Hub Price $/MMBtu     Temp  Production MMCF  Storage BCFE  \
# DOY
# 321                     3.46  41.1111        2644937.0        3840.0
#
#      Reserves BCFE  Consumption MMCF
# DOY
# 321       324303.0         2008815.0

# %% [markdown]
# ### The avg. highest levels of Natural Gas storage in the last 10 years happened in the Middle of November

# %%
df_group[df_group['Storage BCFE'] == df_group['Storage BCFE'].min()]
# Out:
#      Henry Hub Price $/MMBtu     Temp  Production MMCF  Storage BCFE  \
# DOY
# 83                      2.97  44.6146        2543747.0        1614.0
#
#      Reserves BCFE  Consumption MMCF
# DOY
# 83        324303.0         2679165.0

# %% [markdown]
# ### The avg. lowest levels of Natural Gas storage in the last 10 years happened in the end of March

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.set_xlabel('Day of the Year')
ax.set_ylabel('Consumption MMCF')
ax.set_title("Average Natural Gas Consumption in the US 2010-19", fontsize = 13)
ax.scatter(df_shift_final['DOY'], df_shift_final['Consumption MMCF'], label = 'Consumption', alpha =.3)
ax.plot(df_group.index.values, df_group['Consumption MMCF'] , label = 'Mean Consumption', color = 'y')
ax.legend()

# %%
#df_shift_final.to_csv('data/cleaned_data_together.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df80_temp= pd.read_csv('data/all_temp/us_80_84.csv')
df85_temp= pd.read_csv('data/all_temp/us_85_89.csv')
df90_temp= pd.read_csv('data/all_temp/us_90_94.csv')
df95_temp= pd.read_csv('data/all_temp/us_95_99.csv')
df00_temp= pd.read_csv('data/all_temp/us_00_04.csv')
df05_temp= pd.read_csv('data/all_temp/us_05_09.csv')
df10_temp= pd.read_csv('data/all_temp/us_10_15.csv')
df15_temp= pd.read_csv('data/all_temp/us_15_19.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-99275e4f7a84> in <module>
# ----> 1 df80_temp= pd.read_csv('data/all_temp/us_80_84.csv')
#       2 df85_temp= pd.read_csv('data/all_temp/us_85_89.csv')
#       3 df90_temp= pd.read_csv('data/all_temp/us_90_94.csv')
#       4 df95_temp= pd.read_csv('data/all_temp/us_95_99.csv')
#       5 df00_temp= pd.read_csv('data/all_temp/us_00_04.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/all_temp/us_80_84.csv' does not exist: b'data/all_temp/us_80_84.csv'

# %%
def df_cleaner(df):
    df['DateTime'] = df['DateTime'].map(lambda x:x[:-6])
    df['DateTime'] = pd.to_datetime(df['DateTime'])
    temp = df.columns[-1]
    df_clean = df.rename(index=str, columns={temp: "Temp"})
    return df_clean

# %%
df80 = df_cleaner(df80_temp)
df85 = df_cleaner(df85_temp)
df90 = df_cleaner(df90_temp)
df95 = df_cleaner(df95_temp)
df00 = df_cleaner(df00_temp)
df05 = df_cleaner(df05_temp)
df10 = df_cleaner(df10_temp)
df15 = df_cleaner(df15_temp)

# %%
dftemp = pd.concat([df80, df85, df90, df95, df00, df05, df10, df15])
dftemp.reset_index(drop=True)
# Out:
#         DateTime     Temp
# 0     1980-01-01  33.3999
# 1     1980-01-02  31.6287
# 2     1980-01-03  28.9974
# 3     1980-01-04  28.7272
# 4     1980-01-05  28.8493
# 5     1980-01-06  27.3225
# 6     1980-01-07  23.1487
# 7     1980-01-08  20.9849
# 8     1980-01-09  22.7021
# 9     1980-01-10  30.5071
# 10    1980-01-11  31.0969
# 11    1980-01-12  30.3579
# 12    1980-01-13  36.8008
# 13    1980-01-14  39.2083
# 14    1980-01-15  40.3417
# 15    1980-01-16  39.4183
# 16    1980-01-17  37.7514
# 17    1980-01-18  35.1761
# 18    1980-01-19  31.6827
# 19    1980-01-20  30.0085
# 20    1980-01-21  31.5126
# 21    1980-01-22  30.6522
# 22    1980-01-23  27.7515
# 23    1980-01-24  31.5835
# 24    1980-01-25  29.9019
# 25    1980-01-26  23.1579
# 26    1980-01-27  20.0557
# 27    1980-01-28  18.5884
# 28    1980-01-29  18.1931
# 29    1980-01-30  19.2760
# ...          ...      ...
# 14294 2019-02-12  30.4407
# 14295 2019-02-13  31.3905
# 14296 2019-02-14  34.4626
# 14297 2019-02-15  32.4081
# 14298 2019-02-16  29.0892
# 14299 2019-02-17  27.4087
# 14300 2019-02-18  23.2470
# 14301 2019-02-19  22.1778
# 14302 2019-02-20  27.3555
# 14303 2019-02-21  29.1303
# 14304 2019-02-22  29.7369
# 14305 2019-02-23  32.8753
# 14306 2019-02-24  29.5965
# 14307 2019-02-25  25.8399
# 14308 2019-02-26  28.1669
# 14309 2019-02-27  30.8332
# 14310 2019-02-28  31.3455
# 14311 2019-03-01  32.2356
# 14312 2019-03-02  29.8650
# 14313 2019-03-03  24.3361
# 14314 2019-03-04  20.6935
# 14315 2019-03-05  23.3083
# 14316 2019-03-06  27.2867
# 14317 2019-03-07  31.3371
# 14318 2019-03-08  35.1228
# 14319 2019-03-09  37.1899
# 14320 2019-03-10  36.4206
# 14321 2019-03-11  36.5454
# 14322 2019-03-12  39.8039
# 14323 2019-03-13  41.4588
#
# [14324 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(dftemp['DateTime'], dftemp['Temp'])

# %%
dftemp.to_csv(path_or_buf='data/temp_all_80_19.csv', index=False)

# %%
dfe80_temp= pd.read_csv('data/east_temp/east_80_89.csv')
dfe90_temp= pd.read_csv('data/east_temp/east_90_99.csv')
dfe00_temp= pd.read_csv('data/east_temp/east_00_09.csv')
dfe10_temp= pd.read_csv('data/east_temp/east_10_19.csv')

# %%
dfe80 = df_cleaner(dfe80_temp)
dfe90 = df_cleaner(dfe90_temp)
dfe00 = df_cleaner(dfe00_temp)
dfe10 = df_cleaner(dfe10_temp)

# %%
dfetemp = pd.concat([dfe80, dfe90, dfe00, dfe10])
dfetemp.reset_index(drop=True)
# Out:
#         DateTime     Temp
# 0     1980-01-01  33.1484
# 1     1980-01-02  32.2392
# 2     1980-01-03  30.0439
# 3     1980-01-04  28.3447
# 4     1980-01-05  27.4212
# 5     1980-01-06  29.0163
# 6     1980-01-07  27.2286
# 7     1980-01-08  23.1661
# 8     1980-01-09  22.6915
# 9     1980-01-10  32.1145
# 10    1980-01-11  39.6680
# 11    1980-01-12  26.8380
# 12    1980-01-13  34.2021
# 13    1980-01-14  38.3927
# 14    1980-01-15  42.4794
# 15    1980-01-16  43.9182
# 16    1980-01-17  41.5621
# 17    1980-01-18  39.9904
# 18    1980-01-19  37.5373
# 19    1980-01-20  35.6778
# 20    1980-01-21  35.0263
# 21    1980-01-22  35.4033
# 22    1980-01-23  26.8549
# 23    1980-01-24  29.5045
# 24    1980-01-25  32.1435
# 25    1980-01-26  27.9450
# 26    1980-01-27  24.8815
# 27    1980-01-28  23.4876
# 28    1980-01-29  21.2158
# 29    1980-01-30  21.2247
# ...          ...      ...
# 14290 2019-02-12  37.6408
# 14291 2019-02-13  32.5468
# 14292 2019-02-14  37.5971
# 14293 2019-02-15  35.3894
# 14294 2019-02-16  31.7961
# 14295 2019-02-17  33.3932
# 14296 2019-02-18  30.0889
# 14297 2019-02-19  27.7477
# 14298 2019-02-20  34.3735
# 14299 2019-02-21  37.2634
# 14300 2019-02-22  38.2555
# 14301 2019-02-23  42.6517
# 14302 2019-02-24  37.8417
# 14303 2019-02-25  28.5638
# 14304 2019-02-26  30.6835
# 14305 2019-02-27  33.7226
# 14306 2019-02-28  31.8376
# 14307 2019-03-01  33.4245
# 14308 2019-03-02  34.4883
# 14309 2019-03-03  29.0388
# 14310 2019-03-04  21.4036
# 14311 2019-03-05  21.4619
# 14312 2019-03-06  23.1517
# 14313 2019-03-07  28.1070
# 14314 2019-03-08  36.4428
# 14315 2019-03-09  43.1379
# 14316 2019-03-10  43.7086
# 14317 2019-03-11  41.8948
# 14318 2019-03-12  42.4044
# 14319 2019-03-13  48.4603
#
# [14320 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(30,5))
ax.plot(dftemp['DateTime'], dftemp['Temp'])
ax.plot(dfetemp['DateTime'], dfetemp['Temp'], alpha=0.5)

# %%
dfetemp.to_csv(path_or_buf='data/temp_east_80_19.csv', index=False)

# %%
dfw80_temp= pd.read_csv('data/west_temp/west_80_89.csv')
dfw90_temp= pd.read_csv('data/west_temp/west_90_99.csv')
dfw00_temp= pd.read_csv('data/west_temp/west_00_09.csv')
dfw10_temp= pd.read_csv('data/west_temp/west_10_19.csv')

# %%
dfw80 = df_cleaner(dfw80_temp)
dfw90 = df_cleaner(dfw90_temp)
dfw00 = df_cleaner(dfw00_temp)
dfw10 = df_cleaner(dfw10_temp)

# %%
dfwtemp = pd.concat([dfw80, dfw90, dfw00, dfw10])
dfwtemp.reset_index(drop=True)
# Out:
#         DateTime     Temp
# 0     1980-01-01  34.4919
# 1     1980-01-02  32.0934
# 2     1980-01-03  29.1942
# 3     1980-01-04  30.1401
# 4     1980-01-05  31.1869
# 5     1980-01-06  26.7966
# 6     1980-01-07  21.2862
# 7     1980-01-08  21.2112
# 8     1980-01-09  24.8499
# 9     1980-01-10  30.3413
# 10    1980-01-11  24.9663
# 11    1980-01-12  35.1919
# 12    1980-01-13  40.0768
# 13    1980-01-14  40.9446
# 14    1980-01-15  39.0573
# 15    1980-01-16  36.0334
# 16    1980-01-17  35.2369
# 17    1980-01-18  31.7633
# 18    1980-01-19  27.4264
# 19    1980-01-20  25.8859
# 20    1980-01-21  29.1898
# 21    1980-01-22  27.4694
# 22    1980-01-23  29.8035
# 23    1980-01-24  33.8716
# 24    1980-01-25  28.8986
# 25    1980-01-26  20.5090
# 26    1980-01-27  17.4198
# 27    1980-01-28  15.8490
# 28    1980-01-29  17.2242
# 29    1980-01-30  19.2214
# ...          ...      ...
# 14291 2019-02-13  31.5948
# 14292 2019-02-14  32.7778
# 14293 2019-02-15  31.4411
# 14294 2019-02-16  28.2034
# 14295 2019-02-17  23.2432
# 14296 2019-02-18  18.4978
# 14297 2019-02-19  18.4683
# 14298 2019-02-20  22.1508
# 14299 2019-02-21  23.0418
# 14300 2019-02-22  23.2119
# 14301 2019-02-23  24.9168
# 14302 2019-02-24  23.6374
# 14303 2019-02-25  25.1256
# 14304 2019-02-26  27.3522
# 14305 2019-02-27  29.5216
# 14306 2019-02-28  32.1159
# 14307 2019-03-01  32.5335
# 14308 2019-03-02  27.4104
# 14309 2019-03-03  22.1481
# 14310 2019-03-04  21.9520
# 14311 2019-03-05  26.3500
# 14312 2019-03-06  32.2585
# 14313 2019-03-07  35.4085
# 14314 2019-03-08  34.7513
# 14315 2019-03-09  32.4232
# 14316 2019-03-10  30.7567
# 14317 2019-03-11  32.7551
# 14318 2019-03-12  38.0338
# 14319 2019-03-13  35.4391
# 14320 2019-03-14  32.0061
#
# [14321 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(30,5))
#ax.plot(dftemp['DateTime'], dftemp['Temp'])
ax.plot(dfetemp['DateTime'], dfetemp['Temp'])
ax.plot(dfwtemp['DateTime'], dfwtemp['Temp'], alpha=0.5)

# %%
dfwtemp.to_csv(path_or_buf='data/temp_west_80_19.csv', index=False)
